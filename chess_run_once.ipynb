# %% [markdown]
# #Import from Kaggle and Copy to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  ! pip install -q kaggle
  ! mkdir ~/.kaggle
  ! echo '{"username":"alvarbroen","key":"5a598092ccbdcd464a6ed3745888da35"}' > ~/.kaggle/kaggle.json
  ! chmod 600 ~/.kaggle/kaggle.json
  ! kaggle datasets download -d milesh1/35-million-chess-games
  ! unzip -p 35-million-chess-games.zip all_with_filtered_anotations_since1998.txt > data.txt
  ! cp -a data.txt '/content/drive/MyDrive/Colab Notebooks/chess_web/'
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# 35-million-chess-games.zip: Skipping, found more recently modified local copy (use --force to force download)
